# %% [markdown]
# <a href="https://colab.research.google.com/github/hrh2000/CMM560/blob/main/MyFirstColabNotebook_CMM561.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import time
print(time.ctime())
# Out:
# Mon Oct  9 22:28:09 2023

# %%
time.sleep(5)
print (time.ctime())
# Out:
# Mon Oct  9 22:28:14 2023

# %% [markdown]
# This is **bold**.
# This is *italic*.
# This is ~strikethrough~

# %% [markdown]
# $\sqrt{3x-1}+(1+x)^2$

# %%
import numpy as np
from matplotlib import pyplot as plt

ys = 200 + np.random.randn(100)
x = [x for x in range(len(ys))]

plt.plot(x, ys, '-')
plt.fill_between(x, ys, 195, where=(ys > 195), facecolor='g', alpha=0.6)

plt.title("Sample Visualization")
plt.show()
